# %%
import random

from markov import MName
from names import PLACES, MALE_NAMES

# %%
species = [
"Cave Dwarf",
"River Dwarf",
"High Elf",
"Wood Elf",
"Dark Elf",
"Mountain Elf",
"Forest Child",
"Bearman",
"Birdman",
"Centaur",
"Cyclops",
"Halfling",
"Lizardman",
"Minotaur",
"Vampire",
"True Vampire",
"Werewolf",
"Wolf Man",
"Human",
"Nephilim",
"Half Breed",
"Goblin",
"Fire Imp",
"Poison Imp",
"Orc",
"Angel",
"Fairy",
"Ghost",
"Poltergeist",
"Skeleton",
"Zombie",
"Troll",
"Ancient Spirit",
"Nature Spirit",
"Silver Vampire",
"Guardian Spirit",
"Beast of Burden",
"Reaper",
"Wildman",
"Hobgoblin",
"Amarok",
"Fenrir",
"Clay Golem",
"Rock Golem",
"Metal Golem",
"Gremlins",
"Kelpie",
"Fire Dragon",
"Storm Dragon",
"Ancient Dragon",
"Ogre",
"Pegasus",
"Phoenix",
"Unicorn",
"Valkyrie",
"Basilisk",
"Chimera",
"Gorgon",
"Griffin",
]

titles = [
"Barbarian",
"Knight",
"Royal Guard",
"Hoplite",
"Incantation Knight",
"Slayer",
"Assassin",
"Thief",
"Murderer",
"Brute",
"Archer",
"Slinger",
"Enchanted Bowman",
"Sniper",
"Monk",
"Holy Person",
"Conjurer",
"Shaman",
"Necromancer",
"Witch",
"Wizard",
"Sorcerer",
"Warlock",
"Lycanthrope",
"Greyback",
"Vampire",
"Silver Vampire,",
"Angel",
"Great Spirit",
"Lich",
"Greater Lich",
"Lich King",
"Elder Lich",
"Beggar",
]

# %%
name_generator = MName(PLACES, chainlen = 2)
for _ in range(10):
    name = name_generator.New()
    title = random.choice(titles)
    print(name, "the", title)
# Out:
# Ara the Vampire
# Gabika the Lycanthrope
# Kimbi the Angel
# Safiya the Incantation Knight
# Trist the Angel
# Kerryl the Thief
# Valliena the Greyback
# Des the Greyback
# Gabria the Conjurer
# Periarah the Knight
